# %% [markdown]
# 연구원들은 발톱의 흔한 감염인 *발톱 피부사상균 손발톱진균증*에 대한 두 가지 경구 치료의 효과를 조사하기 위한 임상 시험을 수행했습니다. 여기에 몇 가지 배경이 있습니다.
#
# 발톱 균류로 널리 알려진 조갑진균증은 손톱을 손상시키고 때로는 파괴할 수 있을 뿐만 아니라 환자에게 사회적 및 자기 이미지 문제로 이어질 수 있는 상당히 흔한 상태입니다. 전 세계 인구의 2~18%, 미국 인구의 최대 5%가 어떤 형태의 조갑진균증에 시달리는 것으로 추정됩니다. 18세 미만의 어린이에게는 발병 가능성이 드물지만 나이가 들면서 증가하며 최대
# 48%의 사람들이 70세까지 적어도 한 번은 에피소드를 경험했습니다. 엄지발가락과 새끼발가락이 발병할 가능성이 가장 높습니다. 꼭 끼는 신발이나 양말, 샤워실과 탈의실과 같은 공용 시설의 공유, 발톱 광택제는 모두 조갑진균증의 발병과 관련이 있는 것으로 생각됩니다.
#
# 조갑진균증은 발톱 자체가 두꺼워지고 자라며 부스러기로 딱딱해지는 발톱의 변색으로 구별됩니다. 이 상태는 종종 악취가 나는 냄새를 동반합니다.
# 손톱 아래에 이물질이 축적되어 발생합니다. 다양한 형태의 질병에서 손발톱이 부서지고 점차 떨어질 수 있으며, 신발을 신었을 때 극도의 불편함을 유발하거나 표면이 부드럽고 가루가 될 정도로 두꺼워질 수 있습니다.
#
# 조갑진균증은 피부사상균으로 알려진 여러 유형의 진균과 비피부사상균 효모 또는 곰팡이에 의해 유발될 수 있습니다. 연구자들이 수행한 연구는
# 피부사상균으로 인한 특정 유형.
#
# 발톱 피부사상균 손발톱진균증의 치료에 대한 표준 접근법은 가능한 한 많은 발톱의 감염된 부분을 제거한 후 국소 항진균성 연고를 바르거나 경구 항진균제로 치료하는 과정을 포함하며, 일반적으로 더 나은 결과를 얻을 수 있습니다. 연고보다 얻은 것. 연구원들이 수행한 연구는 두 가지 경구 약물인 terbinane(250mg/day로 제공, 치료 1로 표시됨)의 비교에 초점을 맞췄습니다.
# 아래) 및 이트라코나졸(200mg/일로 제공, 아래 치료 2로 표시됨).
#
# 재판은 다음과 같이 진행되었습니다. 엄지발가락에 진행성 발톱 피부사상균 손발톱진균증이 있는 200명의 환자를 모집했고, 각각은 위에서 설명한 대로 감염된 손톱을 제거하는 의사를 만났습니다. 그런 다음 각 피험자는 무작위로 테르비난 치료에 배정되었습니다.
# (치료 1) 또는 이트라코나졸 (치료 2). 치료를 시작하기 직전에 발톱의 손상되지 않은 부분(따라서 제거되지 않은 부분)의 길이를 기록했습니다(밀리미터 단위). 그런 다음 1개월, 2개월, 3개월, 6개월, 12개월에 각 피험자가 돌아와서 손톱의 손상되지 않은 부분의 길이를 다시 측정했습니다. 직관적으로, 손톱이 자라면서(치료 효과로 인해 조갑진균증의 징후가 없기를 바랍니다), 이 길이는 다음과 같습니다.
# 치료가 효과가 있는 경우 증가하고 치료가 좋아지면 손상되지 않은 손톱이 더 길어집니다.
# 평균 길이.
#
# 또한 각 피험자에 대해 성별과 피험자가 체육관이나 헬스클럽을 방문하는 빈도의 지표가 기록되었습니다(따라서 공유 라커룸 및/또는 샤워실을 사용할 수 있음).
#
# 데이터는 `toenail.txt` 파일에서 사용할 수 있습니다. 데이터는 관찰당 하나의 데이터 레코드 형태로 표시됩니다. 데이터 세트의 열은 다음과 같습니다.
#
# 1. 주제 ID
# 2. 헬스클럽 빈도 지표(= 주 1회 이하이면 0, 주 1회 이상이면 1)
# 3. 성별 표시(= 여성이면 0, 남성이면 1)
# 4. 월
# 5. 영향을 받지 않는 손톱 길이(응답, mm)
# 6. 치료 지표 (= 테르비난인 경우 1, 이트라코나졸인 경우 = 2)
#
# 연구원들은 다음과 같이 귀하에게 언급한 몇 가지 질문을 했습니다.
#
# - 이 두 가지 경구용 약물이 발톱에 미치는 영향이 다르다는 증거가 있습니까?
# 손발톱의 손상되지 않은 부분의 길이에 의해 반영되는 피부사상균 조갑진균증?
# - 12개월 동안 테르비난과 이트라코나졸을 투여받은 피험자 사이에 손발톱의 손상되지 않은 부분의 길이 변화 패턴에 차이가 있습니까? 하나
# 치료 결과가 더 빨리 표시됩니까?
#
# - 연구가 끝날 때 손톱의 손상되지 않은 부분의 길이 차이는 무엇입니까? 치료 중 하나가 평균적으로 더 긴 길이를 생성한다는 증거가 있습니까?
# 12개월 후에 다른 것보다?
# - 최근 문헌 보고에 따르면 남성은 여성보다 조갑진균증이 더 심각한 경우가 많습니다. 이것은 길이 사이의 연관성에 의해 반영됩니다.
# 연구 시작 시 이 모집단에서 손톱과 성별의 영향을 받지 않은 부분(
# 치료), 평균적으로 남성의 길이가 여성보다 짧습니다(즉,
# 이 질병은 남성의 손톱에 더 많은 영향을 미칩니다. 이것이 다음과 같다는 증거가 있습니까?
# 사례?
# - 위에서 언급한 바와 같이 공용 라커룸과 샤워실에서 보내는 시간은 조갑진균증이 발생하면서 먹었습니다. 최근 보고서에 따르면 질병의 중증도도 이러한 관행과 관련이 있다는 가설이 있습니다. 이 데이터에 체육관이나 헬스클럽에서 일주일에 하루 이상을 보내는 이 모집단의 피험자가 다음과 같은 증거가 있습니까?
# 연구를 시작할 때 시간을 덜 보낸 사람들과 손톱 길이가 다릅니다.
# 치료)? (누군가는 더 많이 지출하는 사람들에게 더 짧은 길이가 나타날 것이라고 기대할 수 있습니다.
# 이것이 사실이라면 시간.)
# - 테르비난을 복용하는 피험자의 손톱 길이 변화 패턴과 성별 및/또는 헬스클럽 빈도 사이에 연관성이 있습니까? 이것은 이 약이
# 어떤 종류의 주제에서 다른 주제에 비해 더 신속하게 안도합니다.
# - 이트라코나졸을 복용하는 피험자의 손톱 길이 변화 패턴과 성별 및/또는 헬스클럽 빈도 사이에 연관성이 있습니까? 이것은 이 약이
# 어떤 종류의 주제에서 다른 주제에 비해 더 신속하게 구호를 가져옵니다.
