# %% [markdown]
# ## 과제2

# %% [markdown]
# `-` scatter plot의 색깔을 붉은색으로 바꿔서 그려보자.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(43052)
x=np.random.normal(size=10000)
y=np.random.normal(size=10000)

# %%
plt.scatter(x,y,alpha=0.05,c='red')
