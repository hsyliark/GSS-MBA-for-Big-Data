# %%
# 3(a)
hist((runif(100)>0.7)*1)
# Out:
# Plot with title “Histogram of (runif(100) > 0.7) * 1”

# %%
#3(b)
b<-runif(100*10)<0.3 
b<-b*1
dim(b)<-c(100,10)
hist(apply(b,1,sum))
# Out:
# Plot with title “Histogram of apply(b, 1, sum)”

# %%
# 4. 
U1<-runif(10000)*0.5
U2<-runif(10000)*0.5
hist(U2+U1)
# Out:
# Plot with title “Histogram of U2 + U1”

# %%
# 5 
U<-runif(10000)
X<-0*(U>0 & U<0.1)+1*(U>0.1 & U<0.3) + 2*(U>0.3 & U<0.5) + 3*(U>0.5 & U<0.7) + 4*(U>0.7)

# %%
hist(X)
# Out:
# Plot with title “Histogram of X”

# %%
## 8. 
X<- rexp(1000000)
Y<- rexp(1000000)
G<- X+Y

# %%
hist(G)
# Out:
# Plot with title “Histogram of G”

# %% [markdown]
# pdf of $Gamma(\alpha,\beta)=\frac{1}{\beta^\alpha \Gamma(\alpha)}x^{\alpha-1}e^{-x/\beta}$

# %% [markdown]
# pdf of $Gamma(2,1)=xe^{-x}$

# %% [markdown]
# $\int_0^{\infty}x(x-1)(x-2)(x-3)e^{-x}dx=E\big((X-1)(X-2)(X-3)\big)$, where $X \sim \Gamma(2,1)$

# %%
mean((G-1)*(G-2)*(G-3))
# Out:
# [1] 3.996304

# %%
A,B,F
